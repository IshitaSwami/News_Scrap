# %%
import pandas as pd
import requests

# %%
API_KEY = "ab4c9e0a-8814-4752-bb80-ca90d1d169f4"

# %%
url = "https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=1"

# %%
urllist = []

# %%
for i in range(1,16):
    a = "https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page="
    b = str(i)
    c = a+b
    urllist.append(c)

# %%
urllist
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=ab4c9e0a-8814-4752-bb80-ca90d1d169f4&type=article&page=6',
# ...

# %%
response = requests.get(url)
x=response.json()
x
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 150,
#   'startIndex': 1,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 15,
#   'orderBy': 'newest',
#   'tag': {'id': 'world/narendra-modi',
#    'type': 'keyword',
#    'sectionId': 'world',
#    'sectionName': 'World news',
#    'webTitle': 'Narendra Modi',
#    'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#    'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#   'results': [{'id': 'media/2023/jul/02/journalist-ravish-kumar-india-while-we-watched-modi',
#     'type': 'article',
#     'sectionId': 'media',
#     'sectionName': 'Media',
#     'webPublicationDate': '2023-07-02T09:00:38Z',
#     'webTitle': '‘Resistance is possible’: Ravish Kumar, the broadcaster risking his life to tell the truth about India\u200b today\u200b',
#     'webUrl': 'https://www.theguardian.com/media/2023/jul/02/journalist-ravish-kumar-india-while-we-watched-modi',
# ...

# %%
info = []

# %%
def json(url1):
    response = requests.get(url)
    x = response.json()
    info.append(x)

# %%
output = [json(url1) for url1 in urllist]

# %%
len(info)
# Out:
# 15

# %%
info[14]['response']['results'][9]['webTitle']
# Out:
# '‘India is now a linchpin’: US looks to Narendra Modi’s visit to counter China'

# %%
finallist = []

# %%
try:
    for k in range(0,16):
        for j in range(0,9):
            value = dict(webTitle = info[k]['response']['results'][j]['webTitle'],
        sectionName = info[k]['response']['results'][j]['sectionName'],
        webPublicationDate = info[k]['response']['results'][j]['webTitle'])
        finallist.append(value)
except IndexError:
    print("done")
# Out:
# done

# %%
finallist
# Out:
# [{'webTitle': '‘Resistance is possible’: Ravish Kumar, the broadcaster risking his life to tell the truth about India\u200b today\u200b',
#   'sectionName': 'Media',
#   'webPublicationDate': '‘Resistance is possible’: Ravish Kumar, the broadcaster risking his life to tell the truth about India\u200b today\u200b'},
#  {'webTitle': 'Opposition leader Rahul Gandhi begins two-day visit to unrest-hit Manipur',
#   'sectionName': 'World news',
#   'webPublicationDate': 'Opposition leader Rahul Gandhi begins two-day visit to unrest-hit Manipur'},
#  {'webTitle': 'Amid the battle of the giants, a new global order struggles to take shape | Simon Tisdall',
#   'sectionName': 'Opinion',
#   'webPublicationDate': 'Amid the battle of the giants, a new global order struggles to take shape | Simon Tisdall'},
#  {'webTitle': 'Modi’s US visit prompts condemnation and protest from Muslim leaders',
#   'sectionName': 'World news',
# ...

# %%
datanew = pd.DataFrame(finallist)
datanew
# Out:
#                                               webTitle sectionName  \
# 0    ‘Resistance is possible’: Ravish Kumar, the br...       Media
# 1    Opposition leader Rahul Gandhi begins two-day ...  World news
# 2    Amid the battle of the giants, a new global or...     Opinion
# 3    Modi’s US visit prompts condemnation and prote...  World news
# 4    Biden announces raft of new deals with Modi am...     US news
# ..                                                 ...         ...
# 768  Narendra Modi does yoga in New York as US stat...  World news
# 769  Narendra Modi does yoga in New York as US stat...  World news
# 770  Narendra Modi does yoga in New York as US stat...  World news
# 771  Narendra Modi does yoga in New York as US stat...  World news
# 772  Narendra Modi does yoga in New York as US stat...  World news
#
#                                     webPublicationDate
# 0    ‘Resistance is possible’: Ravish Kumar, the br...
# ...

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 150,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 15,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'media/2023/jul/02/journalist-ravish-kumar-india-while-we-watched-modi',
#      'type': 'article',
#      'sectionId': 'media',
#      'sectionName': 'Media',
#      'webPublicationDate': '2023-07-02T09:00:38Z',
#      'webTitle': '‘Resistance is possible’: Ravish Kumar, the broadcaster risking his life to tell the truth about India\u200b today\u200b',
#      'webUrl': 'https://www.theguardian.com/media/2023/jul/02/journalist-ravish-kumar-india-while-we-watched-modi',
# ...

# %%
info[0]['response']['pages']
# Out:
# 15

# %%
info[0]['response']['total']
# Out:
# 150

# %%
info
